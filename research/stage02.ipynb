# %%
import os
os.chdir("../")

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class PrepareBaseModelConfig:
    root_dir: Path
    base_model_path: Path
    updated_base_model_path: Path
    params_image_size: list
    params_learning_rate: float
    params_include_top: bool
    params_weights: str
    params_classes: int

# %%
from deepClassifier.constants import *
from deepClassifier.utils import read_yaml, create_directories

# %%
from deepClassifier import Singleton


class ConfigurationManager(Singleton):
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])

    def get_prepare_base_model_config(self) -> PrepareBaseModelConfig:
        config = self.config.prepare_base_model
        
        create_directories([config.root_dir])

        prepare_base_model_config = PrepareBaseModelConfig(
            root_dir=Path(config.root_dir),
            base_model_path=Path(config.base_model_path),
            updated_base_model_path=Path(config.updated_base_model_path),
            params_image_size=self.params.IMAGE_SIZE,
            params_learning_rate=self.params.LEARNING_RATE,
            params_include_top=self.params.INCLUDE_TOP,
            params_weights=self.params.WEIGHTS,
            params_classes=self.params.CLASSES
        )

        return prepare_base_model_config

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf

class PrepareBaseModel:
    def __init__(self, config: PrepareBaseModelConfig):
        self.config = config

    def get_base_model(self):
        self.model = tf.keras.applications.vgg16.VGG16(
            input_shape=self.config.params_image_size,
            weights=self.config.params_weights,
            include_top=self.config.params_include_top
        )

        self.save_model(path=self.config.base_model_path, model=self.model)


    @staticmethod
    def _prepare_full_model(model, classes, freeze_all, freeze_till, learning_rate):
        if freeze_all:
            for layer in model.layers:
                model.trainable = False
        elif (freeze_till is not None) and (freeze_till > 0):
            for layer in model.layers[:-freeze_till]:
                model.trainable = False

        flatten_in = tf.keras.layers.Flatten()(model.output)
        prediction = tf.keras.layers.Dense(
            units=classes,
            activation="softmax"
        )(flatten_in)

        full_model = tf.keras.models.Model(
            inputs=model.input,
            outputs=prediction
        )

        full_model.compile(
            optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
            loss=tf.keras.losses.CategoricalCrossentropy(),
            metrics=["accuracy"]
        )

        full_model.summary()
        return full_model

    def update_base_model(self):
        self.full_model = self._prepare_full_model(
            model=self.model,
            classes=self.config.params_classes,
            freeze_all=True,
            freeze_till=None,
            learning_rate=self.config.params_learning_rate
        )

        self.save_model(path=self.config.updated_base_model_path, model=self.full_model)

    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)
# Out:
# Level 1:tensorflow:Registering FakeQuantWithMinMaxArgs (<function _FakeQuantWithMinMaxArgsGradient at 0x000001E478E9DDC0>) in gradient.
# Level 1:tensorflow:Registering FakeQuantWithMinMaxVars (<function _FakeQuantWithMinMaxVarsGradient at 0x000001E478FC69D0>) in gradient.
# Level 1:tensorflow:Registering FakeQuantWithMinMaxVarsPerChannel (<function _FakeQuantWithMinMaxVarsPerChannelGradient at 0x000001E478E9DF70>) in gradient.
# Level 1:tensorflow:Registering QuantizeAndDequantizeV4 (<function _QuantizeAndDequantizeV4Grad at 0x000001E478FC6A60>) in gradient.
# Level 1:tensorflow:Registering QuantizeAndDequantizeV4Grad (<function _QuantizeAndDequantizeV4GradGrad at 0x000001E478FC6C10>) in gradient.
# Level 1:tensorflow:Registering TensorListConcatLists (None) in gradient.
# Level 1:tensorflow:Registering TensorListElementShape (None) in gradient.
# Level 1:tensorflow:Registering TensorListLength (None) in gradient.
# Level 1:tensorflow:Registering TensorListPushBackBatch (None) in gradient.
# Level 1:tensorflow:Registering TensorListPushBack (<function _PushBackGrad at 0x000001E47909D9D0>) in gradient.
# Level 1:tensorflow:Registering TensorListPopBack (<function _PopBackGrad at 0x000001E47909D430>) in gradient.
# Level 1:tensorflow:Registering TensorListStack (<function _TensorListStackGrad at 0x000001E47909DA60>) in gradient.
# Level 1:tensorflow:Registering TensorListConcatV2 (<function _TensorListConcatGrad at 0x000001E47909DAF0>) in gradient.
# Level 1:tensorflow:Registering TensorListConcat (<function _TensorListConcatGrad at 0x000001E47909DAF0>) in gradient.
# Level 1:tensorflow:Registering TensorListSplit (<function _TensorListSplitGrad at 0x000001E47909DC10>) in gradient.
# Level 1:tensorflow:Registering TensorListFromTensor (<function _TensorListFromTensorGrad at 0x000001E47909DB80>) in gradient.
# Level 1:tensorflow:Registering TensorListGetItem (<function _TensorListGetItemGrad at 0x000001E47909DCA0>) in gradient.
# Level 1:tensorflow:Registering TensorListSetItem (<function _TensorListSetItemGrad at 0x000001E47909DD30>) in gradient.
# Level 1:tensorflow:Registering TensorListResize (<function _TensorListResizeGrad at 0x000001E47909DDC0>) in gradient.
# Level 1:tensorflow:Registering TensorListGather (<function _TensorListGatherGrad at 0x000001E47909DE50>) in gradient.
# Level 1:tensorflow:Registering TensorListScatterV2 (<function _TensorListScatterGrad at 0x000001E47909DEE0>) in gradient.
# Level 1:tensorflow:Registering TensorListScatter (<function _TensorListScatterGrad at 0x000001E47909DEE0>) in gradient.
# Level 1:tensorflow:Registering TensorListScatterIntoExistingList (<function _TensorListScatterIntoExistingListGrad at 0x000001E4790A6040>) in gradient.
# Level 1:tensorflow:Registering MatMul,flops (<function _calc_mat_mul_flops at 0x000001E4791C4F70>) in statistical functions.
# Level 1:tensorflow:Registering BatchMatMulV3,flops (<function _calc_batch_mat_mul_flops at 0x000001E47922CCA0>) in statistical functions.
# Level 1:tensorflow:Registering BatchMatMulV2,flops (<function _calc_batch_mat_mul_flops at 0x000001E47922CCA0>) in statistical functions.
# Level 1:tensorflow:Registering BatchMatMul,flops (<function _calc_batch_mat_mul_flops at 0x000001E47922CCA0>) in statistical functions.
# Level 1:tensorflow:Registering AccumulateNV2 (<function _accumulate_n_grad at 0x000001E47923E040>) in gradient.
# Level 1:tensorflow:Registering cond_context ((<class 'tensorflow.core.protobuf.control_flow_pb2.CondContextDef'>, <function CondContext.to_proto at 0x000001E47930EDC0>, <function CondContext.from_proto at 0x000001E47930EE50>)) in proto functions.
# Level 1:tensorflow:Registering while_context ((<class 'tensorflow.core.protobuf.control_flow_pb2.WhileContextDef'>, <function WhileContext.to_proto at 0x000001E4793100D0>, <function WhileContext.from_proto at 0x000001E4793101F0>)) in proto functions.
# Level 1:tensorflow:Registering EnsureShape (<function _ensure_shape_grad at 0x000001E4793800D0>) in gradient.
# Level 1:tensorflow:Registering RaggedTensorToSparse (<function _ragged_tensor_to_sparse_gradient at 0x000001E4793E5040>) in gradient.
# Level 1:tensorflow:Registering BitwiseAnd (None) in gradient.
# Level 1:tensorflow:Registering BitwiseOr (None) in gradient.
# Level 1:tensorflow:Registering BitwiseXor (None) in gradient.
# Level 1:tensorflow:Registering Invert (None) in gradient.
# Level 1:tensorflow:Registering PopulationCount (None) in gradient.
# Level 1:tensorflow:Registering LeftShift (None) in gradient.
# Level 1:tensorflow:Registering RightShift (None) in gradient.
# Level 1:tensorflow:Registering StatelessMultinomial (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomBinomial (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomNormal (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomPoisson (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomUniform (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomUniformInt (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomUniformFullInt (None) in gradient.
# Level 1:tensorflow:Registering StatelessTruncatedNormal (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomNormalV2 (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomUniformV2 (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomUniformIntV2 (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomUniformFullIntV2 (None) in gradient.
# Level 1:tensorflow:Registering StatelessTruncatedNormalV2 (None) in gradient.
# Level 1:tensorflow:Registering StatelessRandomShuffle (None) in gradient.
# Level 1:tensorflow:Registering RandomIndexShuffle (None) in gradient.
# Level 1:tensorflow:Registering RandomStandardNormal (None) in gradient.
# Level 1:tensorflow:Registering ParameterizedTruncatedNormal (None) in gradient.
# Level 1:tensorflow:Registering TruncatedNormal (None) in gradient.
# Level 1:tensorflow:Registering RandomUniform (None) in gradient.
# Level 1:tensorflow:Registering RandomShuffle (None) in gradient.
# Level 1:tensorflow:Registering Multinomial (None) in gradient.
# Level 1:tensorflow:Registering ReadVariableOp (<function _ReadGrad at 0x000001E47A786A60>) in gradient.
# Level 1:tensorflow:Registering ResourceGather (<function _GatherGrad at 0x000001E47A7BD1F0>) in gradient.
# Level 1:tensorflow:Registering variables ((<class 'tensorflow.core.framework.variable_pb2.VariableDef'>, <function _to_proto_fn at 0x000001E47A7BD310>, <function _from_proto_fn at 0x000001E47A7BD280>)) in proto functions.
# Level 1:tensorflow:Registering trainable_variables ((<class 'tensorflow.core.framework.variable_pb2.VariableDef'>, <function _to_proto_fn at 0x000001E47A7BD310>, <function _from_proto_fn at 0x000001E47A7BD280>)) in proto functions.
# Level 1:tensorflow:Registering moving_average_variables ((<class 'tensorflow.core.framework.variable_pb2.VariableDef'>, <function _to_proto_fn at 0x000001E47A7BD310>, <function _from_proto_fn at 0x000001E47A7BD280>)) in proto functions.
# Level 1:tensorflow:Registering local_variables ((<class 'tensorflow.core.framework.variable_pb2.VariableDef'>, <function _to_proto_fn at 0x000001E47A7BD310>, <function _from_proto_fn at 0x000001E47A7BD280>)) in proto functions.
# Level 1:tensorflow:Registering model_variables ((<class 'tensorflow.core.framework.variable_pb2.VariableDef'>, <function _to_proto_fn at 0x000001E47A7BD310>, <function _from_proto_fn at 0x000001E47A7BD280>)) in proto functions.
# Level 1:tensorflow:Registering global_step ((<class 'tensorflow.core.framework.variable_pb2.VariableDef'>, <function _to_proto_fn at 0x000001E47A7BD310>, <function _from_proto_fn at 0x000001E47A7BD280>)) in proto functions.
# Level 1:tensorflow:Registering metric_variables ((<class 'tensorflow.core.framework.variable_pb2.VariableDef'>, <function _to_proto_fn at 0x000001E47A7BD310>, <function _from_proto_fn at 0x000001E47A7BD280>)) in proto functions.
# Level 1:tensorflow:Registering Assert (None) in gradient.
# Level 1:tensorflow:Registering VarIsInitializedOp (None) in gradient.
# Level 1:tensorflow:Registering VariableShape (None) in gradient.
# Level 1:tensorflow:Registering ReaderRead (None) in gradient.
# Level 1:tensorflow:Registering ReaderReadUpTo (None) in gradient.
# Level 1:tensorflow:Registering ReaderNumRecordsProduced (None) in gradient.
# Level 1:tensorflow:Registering ReaderNumWorkUnitsCompleted (None) in gradient.
# Level 1:tensorflow:Registering ReaderSerializeState (None) in gradient.
# Level 1:tensorflow:Registering ReaderRestoreState (None) in gradient.
# Level 1:tensorflow:Registering ReaderReset (None) in gradient.
# Level 1:tensorflow:Registering WholeFileReader (None) in gradient.
# Level 1:tensorflow:Registering TextLineReader (None) in gradient.
# Level 1:tensorflow:Registering FixedLengthRecordReader (None) in gradient.
# Level 1:tensorflow:Registering TFRecordReader (None) in gradient.
# Level 1:tensorflow:Registering LMDBReader (None) in gradient.
# Level 1:tensorflow:Registering IdentityReader (None) in gradient.
# Level 1:tensorflow:Registering RegexReplace (None) in gradient.
# Level 1:tensorflow:Registering StringToHashBucket (None) in gradient.
# Level 1:tensorflow:Registering StringToHashBucketFast (None) in gradient.
# Level 1:tensorflow:Registering StringToHashBucketStrong (None) in gradient.
# Level 1:tensorflow:Registering ReduceJoin (None) in gradient.
# Level 1:tensorflow:Registering StringJoin (None) in gradient.
# Level 1:tensorflow:Registering StringSplit (None) in gradient.
# Level 1:tensorflow:Registering AsString (None) in gradient.
# Level 1:tensorflow:Registering EncodeBase64 (None) in gradient.
# Level 1:tensorflow:Registering DecodeBase64 (None) in gradient.
# Level 1:tensorflow:Registering AllToAll (<function _all_to_all_grad at 0x000001E47A91F8B0>) in gradient.
# Level 1:tensorflow:Registering CollectivePermute (<function _collective_permute_grad at 0x000001E47A92CDC0>) in gradient.
# Level 1:tensorflow:Registering CrossReplicaSum (<function _cross_replica_sum_grad at 0x000001E47A91F940>) in gradient.
# Level 1:tensorflow:Registering TPUEmbeddingActivations (<function _embedding_activations_grad at 0x000001E47A92CF70>) in gradient.
# Level 1:tensorflow:Registering _identity_resolver (<function _identity_resolver at 0x000001E47A97DDC0>) in acd_resource_resolvers.
# Level 1:tensorflow:Registering savers ((<class 'tensorflow.core.protobuf.saver_pb2.SaverDef'>, <function Saver.to_proto at 0x000001E47AA13430>, <function Saver.from_proto at 0x000001E47AA134C0>)) in proto functions.
# Level 1:tensorflow:Registering EagerPyFunc (<function _EagerPyFuncGrad at 0x000001E47AA52940>) in gradient.
# Level 1:tensorflow:Registering PyFunc (None) in gradient.
# Level 1:tensorflow:Registering PyFuncStateless (None) in gradient.
# Level 1:tensorflow:Registering Print (<function _PrintGrad at 0x000001E47AA723A0>) in gradient.
# Level 1:tensorflow:Registering HistogramSummary (None) in gradient.
# Level 1:tensorflow:Registering ImageSummary (None) in gradient.
# Level 1:tensorflow:Registering AudioSummary (None) in gradient.
# Level 1:tensorflow:Registering AudioSummaryV2 (None) in gradient.
# Level 1:tensorflow:Registering MergeSummary (None) in gradient.
# Level 1:tensorflow:Registering ScalarSummary (None) in gradient.
# Level 1:tensorflow:Registering TensorSummary (None) in gradient.
# Level 1:tensorflow:Registering TensorSummaryV2 (None) in gradient.
# Level 1:tensorflow:Registering Timestamp (None) in gradient.
# Level 1:tensorflow:Registering ReduceDataset (None) in gradient.
# Level 1:tensorflow:Registering _resource_resolver (<function _resource_resolver at 0x000001E47AB34DC0>) in acd_resource_resolvers.
# Level 1:tensorflow:Registering LookupTableFind (None) in gradient.
# Level 1:tensorflow:Registering LookupTableFindV2 (None) in gradient.
# Level 1:tensorflow:Registering LookupTableInsert (None) in gradient.
# Level 1:tensorflow:Registering LookupTableInsertV2 (None) in gradient.
# Level 1:tensorflow:Registering LookupTableSize (None) in gradient.
# Level 1:tensorflow:Registering LookupTableSizeV2 (None) in gradient.
# Level 1:tensorflow:Registering HashTable (None) in gradient.
# Level 1:tensorflow:Registering HashTableV2 (None) in gradient.
# Level 1:tensorflow:Registering InitializeTable (None) in gradient.
# Level 1:tensorflow:Registering InitializeTableV2 (None) in gradient.
# Level 1:tensorflow:Registering InitializeTableFromTextFile (None) in gradient.
# Level 1:tensorflow:Registering InitializeTableFromTextFileV2 (None) in gradient.
# Level 1:tensorflow:Registering MutableDenseHashTable (None) in gradient.
# Level 1:tensorflow:Registering MutableDenseHashTableV2 (None) in gradient.
# Level 1:tensorflow:Registering MutableHashTable (None) in gradient.
# Level 1:tensorflow:Registering MutableHashTableV2 (None) in gradient.
# Level 1:tensorflow:Registering MutableHashTableOfTensors (None) in gradient.
# Level 1:tensorflow:Registering MutableHashTableOfTensorsV2 (None) in gradient.
# Level 1:tensorflow:Registering XlaEinsum (<function _einsum_grad at 0x000001E47AD233A0>) in gradient.
# Level 1:tensorflow:Registering Conv3D,flops (<function _calc_conv3d_flops at 0x000001E47ADD7310>) in statistical functions.
# Level 1:tensorflow:Registering Conv2D,flops (<function _calc_conv_flops at 0x000001E47AE669D0>) in statistical functions.
# Level 1:tensorflow:Registering DepthwiseConv2dNative,flops (<function _calc_depthwise_conv_flops at 0x000001E47ADD74C0>) in statistical functions.
# Level 1:tensorflow:Registering BiasAdd,flops (<function _calc_bias_add_flops at 0x000001E47AE66B80>) in statistical functions.
# Level 1:tensorflow:Registering Dilation2D,flops (<function _calc_dilation2d_flops at 0x000001E47AE741F0>) in statistical functions.
# Level 1:tensorflow:Registering RaggedRange (None) in gradient.
# Level 1:tensorflow:Registering DecodeRaw (None) in gradient.
# Level 1:tensorflow:Registering DecodePaddedRaw (None) in gradient.
# Level 1:tensorflow:Registering ParseTensor (None) in gradient.
# Level 1:tensorflow:Registering SerializeTensor (None) in gradient.
# Level 1:tensorflow:Registering StringToNumber (None) in gradient.
# Level 1:tensorflow:Registering Conv2DBackpropInput (<function _Conv2DBackpropInputGrad at 0x000001E47B1B0C10>) in gradient.
# Level 1:tensorflow:Registering Conv2DBackpropFilter (<function _Conv2DBackpropFilterGrad at 0x000001E47B1C9D30>) in gradient.
# Level 1:tensorflow:Registering DepthwiseConv2dNativeBackpropInput (<function _DepthwiseConv2dNativeBackpropInputGrad at 0x000001E47B176F70>) in gradient.
# Level 1:tensorflow:Registering DepthwiseConv2dNativeBackpropFilter (<function _DepthwiseConv2dNativeBackpropFilterGrad at 0x000001E47B1C9DC0>) in gradient.
# Level 1:tensorflow:Registering Conv3D (<function _Conv3DGrad at 0x000001E47B1C9F70>) in gradient.
# Level 1:tensorflow:Registering Conv3DBackpropInputV2 (<function _Conv3DBackpropInputGrad at 0x000001E47B1C9EE0>) in gradient.
# Level 1:tensorflow:Registering Conv3DBackpropFilterV2 (<function _Conv3DBackpropFilterGrad at 0x000001E47B1DD040>) in gradient.
# Level 1:tensorflow:Registering AvgPool3D (<function _AvgPool3DGrad at 0x000001E47B1C9E50>) in gradient.
# Level 1:tensorflow:Registering AvgPool3DGrad (<function _AvgPool3DGradGrad at 0x000001E47B1DD1F0>) in gradient.
# Level 1:tensorflow:Registering MaxPool3D (<function _MaxPool3DGrad at 0x000001E47B1DD160>) in gradient.
# Level 1:tensorflow:Registering MaxPool3DGrad (<function _MaxPool3DGradGrad at 0x000001E47B1DD0D0>) in gradient.
# Level 1:tensorflow:Registering MaxPool3DGradGrad (<function _MaxPool3DGradGradGrad at 0x000001E47B1DD280>) in gradient.
# Level 1:tensorflow:Registering Softmax (<function _SoftmaxGrad at 0x000001E47B1DD310>) in gradient.
# Level 1:tensorflow:Registering LogSoftmax (<function _LogSoftmaxGrad at 0x000001E47B1DD550>) in gradient.
# Level 1:tensorflow:Registering BiasAdd (<function _BiasAddGrad at 0x000001E47B1DD430>) in gradient.
# Level 1:tensorflow:Registering BiasAddGrad (<function _BiasAddGradGrad at 0x000001E47B1DD4C0>) in gradient.
# Level 1:tensorflow:Registering BiasAddV1 (<function _BiasAddGradV1 at 0x000001E47B1DD670>) in gradient.
# Level 1:tensorflow:Registering Relu (<function _ReluGrad at 0x000001E47B1DD700>) in gradient.
# Level 1:tensorflow:Registering EluGrad (<function _EluGradGrad at 0x000001E47B1DD790>) in gradient.
# Level 1:tensorflow:Registering SeluGrad (<function _SeluGradGrad at 0x000001E47B1DD820>) in gradient.
# Level 1:tensorflow:Registering Relu6 (<function _Relu6Grad at 0x000001E47B1DD3A0>) in gradient.
# Level 1:tensorflow:Registering Relu6Grad (<function _Relu6GradGrad at 0x000001E47B1DD8B0>) in gradient.
# Level 1:tensorflow:Registering LeakyRelu (<function _LeakyReluGrad at 0x000001E47B1DD940>) in gradient.
# Level 1:tensorflow:Registering LeakyReluGrad (<function _LeakyReluGradGrad at 0x000001E47B1DD5E0>) in gradient.
# Level 1:tensorflow:Registering Elu (<function _EluGrad at 0x000001E47B1DD9D0>) in gradient.
# Level 1:tensorflow:Registering Selu (<function _SeluGrad at 0x000001E47B1DDA60>) in gradient.
# Level 1:tensorflow:Registering Softplus (<function _SoftplusGrad at 0x000001E47B1DDB80>) in gradient.
# Level 1:tensorflow:Registering SoftplusGrad (<function _SoftplusGradGrad at 0x000001E47B1DDC10>) in gradient.
# Level 1:tensorflow:Registering Softsign (<function _SoftsignGrad at 0x000001E47B1DDAF0>) in gradient.
# Level 1:tensorflow:Registering ReluGrad (<function _ReluGradGrad at 0x000001E47B1DDCA0>) in gradient.
# Level 1:tensorflow:Registering SoftmaxCrossEntropyWithLogits (<function _SoftmaxCrossEntropyWithLogitsGrad at 0x000001E47B1DDD30>) in gradient.
# Level 1:tensorflow:Registering SparseSoftmaxCrossEntropyWithLogits (<function _SparseSoftmaxCrossEntropyWithLogitsGrad at 0x000001E47B1DDE50>) in gradient.
# Level 1:tensorflow:Registering Conv2D (<function _Conv2DGrad at 0x000001E47B1DDEE0>) in gradient.
# Level 1:tensorflow:Registering DepthwiseConv2dNative (<function _DepthwiseConv2dNativeGrad at 0x000001E47B1DDF70>) in gradient.
# Level 1:tensorflow:Registering Dilation2D (<function _Dilation2DGrad at 0x000001E47B1E3040>) in gradient.
# Level 1:tensorflow:Registering LRN (<function _LRNGrad at 0x000001E47B1E30D0>) in gradient.
# Level 1:tensorflow:Registering AvgPool (<function _AvgPoolGrad at 0x000001E47B1E31F0>) in gradient.
# Level 1:tensorflow:Registering AvgPoolGrad (<function _AvgPoolGradGrad at 0x000001E47B1E3310>) in gradient.
# Level 1:tensorflow:Registering MaxPool (<function _MaxPoolGrad at 0x000001E47B1E3280>) in gradient.
# Level 1:tensorflow:Registering MaxPoolV2 (<function _MaxPoolGradV2 at 0x000001E47B1E3160>) in gradient.
# Level 1:tensorflow:Registering MaxPoolWithArgmax (<function _MaxPoolGradWithArgmax at 0x000001E47B1E3430>) in gradient.
# Level 1:tensorflow:Registering MaxPoolGrad (<function _MaxPoolGradGrad at 0x000001E47B1E33A0>) in gradient.
# Level 1:tensorflow:Registering MaxPoolGradV2 (<function _MaxPoolGradGradV2 at 0x000001E47B1E35E0>) in gradient.
# Level 1:tensorflow:Registering MaxPoolGradGrad (<function _MaxPoolGradGradGrad at 0x000001E47B1E3550>) in gradient.
# Level 1:tensorflow:Registering FractionalMaxPool (<function _FractionalMaxPoolGrad at 0x000001E47B1E34C0>) in gradient.
# Level 1:tensorflow:Registering FractionalAvgPool (<function _FractionalAvgPoolGrad at 0x000001E47B1E3670>) in gradient.
# Level 1:tensorflow:Registering BatchNormWithGlobalNormalization (<function _BatchNormWithGlobalNormalizationGrad at 0x000001E47B1E3790>) in gradient.
# Level 1:tensorflow:Registering FusedBatchNorm (<function _FusedBatchNormGrad at 0x000001E47B1E38B0>) in gradient.
# Level 1:tensorflow:Registering FusedBatchNormV2 (<function _FusedBatchNormV2Grad at 0x000001E47B1E3700>) in gradient.
# Level 1:tensorflow:Registering FusedBatchNormV3 (<function _FusedBatchNormV3Grad at 0x000001E47B1E3940>) in gradient.
# Level 1:tensorflow:Registering FusedBatchNormGrad (<function _FusedBatchNormGradGrad at 0x000001E47B1E3AF0>) in gradient.
# Level 1:tensorflow:Registering FusedBatchNormGradV2 (<function _FusedBatchNormGradGradV2 at 0x000001E47B1E3A60>) in gradient.
# Level 1:tensorflow:Registering FusedBatchNormGradV3 (<function _FusedBatchNormGradGradV3 at 0x000001E47B1E3B80>) in gradient.
# Level 1:tensorflow:Registering L2Loss (<function _L2LossGrad at 0x000001E47B1E3C10>) in gradient.
# Level 1:tensorflow:Registering TopKV2 (<function _TopKGrad at 0x000001E47B1E3CA0>) in gradient.
# Level 1:tensorflow:Registering TopK (<function _TopKGrad at 0x000001E47B1E3CA0>) in gradient.
# Level 1:tensorflow:Registering ApproxTopK (<function _ApproxTopKGradient at 0x000001E47B1E3EE0>) in gradient.
# Level 1:tensorflow:Registering NthElement (<function _NthElementGrad at 0x000001E47B1E3DC0>) in gradient.
# Level 1:tensorflow:Registering IsotonicRegression (<function _IsotonicRegressionGrad at 0x000001E47B1E3F70>) in gradient.
# Level 1:tensorflow:Registering CTCLoss (<function _CTCLossGrad at 0x000001E47B1EA3A0>) in gradient.
# Level 1:tensorflow:Registering CTCLossV2 (<function _CTCLossV2Grad at 0x000001E47B2081F0>) in gradient.
# Level 1:tensorflow:Registering CTCGreedyDecoder (None) in gradient.
# Level 1:tensorflow:Registering CTCBeamSearchDecoder (None) in gradient.
# Level 1:tensorflow:Registering DynamicPartition (<function _DynamicPartitionGrads at 0x000001E47B2154C0>) in gradient.
# Level 1:tensorflow:Registering ParallelDynamicStitch (<function _DynamicStitchGrads at 0x000001E47B23B160>) in gradient.
# Level 1:tensorflow:Registering DynamicStitch (<function _DynamicStitchGrads at 0x000001E47B23B160>) in gradient.
# Level 1:tensorflow:Registering Queue (None) in gradient.
# Level 1:tensorflow:Registering QueueEnqueue (None) in gradient.
# Level 1:tensorflow:Registering QueueEnqueueMany (None) in gradient.
# Level 1:tensorflow:Registering QueueDequeue (None) in gradient.
# Level 1:tensorflow:Registering QueueDequeueMany (None) in gradient.
# Level 1:tensorflow:Registering QueueDequeueUpTo (None) in gradient.
# Level 1:tensorflow:Registering QueueClose (None) in gradient.
# Level 1:tensorflow:Registering QueueSize (None) in gradient.
# Level 1:tensorflow:Registering Stack (None) in gradient.
# Level 1:tensorflow:Registering StackPush (None) in gradient.
# Level 1:tensorflow:Registering StackPop (None) in gradient.
# Level 1:tensorflow:Registering StackClose (None) in gradient.
# Level 1:tensorflow:Registering GetSessionHandle (None) in gradient.
# Level 1:tensorflow:Registering GetSessionHandleV2 (None) in gradient.
# Level 1:tensorflow:Registering GetSessionTensor (None) in gradient.
# Level 1:tensorflow:Registering DeleteSessionTensor (None) in gradient.
# Level 1:tensorflow:Registering SetSize (None) in gradient.
# Level 1:tensorflow:Registering DenseToDenseSetOperation (None) in gradient.
# Level 1:tensorflow:Registering DenseToSparseSetOperation (None) in gradient.
# Level 1:tensorflow:Registering SparseToSparseSetOperation (None) in gradient.
# Level 1:tensorflow:Registering XlaVariadicReduce (None) in gradient.
# Level 1:tensorflow:Registering XlaSharding (<function _sharding_grad at 0x000001E47B360160>) in gradient.
# Level 1:tensorflow:Registering XlaSpmdFullToShardShape (<function _spmd_full_to_shard_shape_grad at 0x000001E47B318B80>) in gradient.
# Level 1:tensorflow:Registering XlaSpmdShardToFullShape (<function _spmd_shard_to_full_shape_grad at 0x000001E47B3601F0>) in gradient.
# Level 1:tensorflow:Registering XlaClusterOutput (<function _XlaClusterOutputGrad at 0x000001E47B3B24C0>) in gradient.
# Level 1:tensorflow:Registering TPUReplicatedInput (None) in gradient.
# Level 1:tensorflow:Registering tpu_replicated_input_resolver (<function tpu_replicated_input_resolver at 0x000001E47B409430>) in acd_resource_resolvers.
# Level 1:tensorflow:Registering Pack (<function _PackGrad at 0x000001E47B4E8550>) in gradient.
# Level 1:tensorflow:Registering Unpack (<function _UnpackGrad at 0x000001E47B500700>) in gradient.
# Level 1:tensorflow:Registering Concat (<function _ConcatGrad at 0x000001E47B500820>) in gradient.
# Level 1:tensorflow:Registering ConcatV2 (<function _ConcatGradV2 at 0x000001E47B500790>) in gradient.
# Level 1:tensorflow:Registering ConcatOffset (None) in gradient.
# Level 1:tensorflow:Registering Slice (<function _SliceGrad at 0x000001E47B500940>) in gradient.
# Level 1:tensorflow:Registering StridedSlice (<function _StridedSliceGrad at 0x000001E47B5008B0>) in gradient.
# Level 1:tensorflow:Registering StridedSliceGrad (<function _StridedSliceGradGrad at 0x000001E47B500A60>) in gradient.
# Level 1:tensorflow:Registering TensorStridedSliceUpdate (<function _TensorStridedSliceUpdateGrad at 0x000001E47B5009D0>) in gradient.
# Level 1:tensorflow:Registering Split (<function _SplitGrad at 0x000001E47B500AF0>) in gradient.
# Level 1:tensorflow:Registering SplitV (<function _SplitVGrad at 0x000001E47B500CA0>) in gradient.
# Level 1:tensorflow:Registering Const (None) in gradient.
# Level 1:tensorflow:Registering Diag (<function _DiagGrad at 0x000001E47B500B80>) in gradient.
# Level 1:tensorflow:Registering DiagPart (<function _DiagPartGrad at 0x000001E47B500DC0>) in gradient.
# Level 1:tensorflow:Registering MatrixDiag (<function _MatrixDiagGrad at 0x000001E47B500D30>) in gradient.
# Level 1:tensorflow:Registering MatrixDiagV2 (<function _MatrixDiagV2Grad at 0x000001E47B500EE0>) in gradient.
# Level 1:tensorflow:Registering MatrixDiagV3 (<function _MatrixDiagV3Grad at 0x000001E47B500F70>) in gradient.
# Level 1:tensorflow:Registering MatrixDiagPart (<function _MatrixDiagPartGrad at 0x000001E47B500E50>) in gradient.
# Level 1:tensorflow:Registering MatrixDiagPartV2 (<function _MatrixDiagPartV2Grad at 0x000001E47B50E040>) in gradient.
# Level 1:tensorflow:Registering MatrixDiagPartV3 (<function _MatrixDiagPartV3Grad at 0x000001E47B500C10>) in gradient.
# Level 1:tensorflow:Registering MatrixSetDiag (<function _MatrixSetDiagGrad at 0x000001E47B50E0D0>) in gradient.
# Level 1:tensorflow:Registering MatrixSetDiagV2 (<function _MatrixSetDiagGradV2 at 0x000001E47B50E160>) in gradient.
# Level 1:tensorflow:Registering MatrixSetDiagV3 (<function _MatrixSetDiagGradV3 at 0x000001E47B50E1F0>) in gradient.
# Level 1:tensorflow:Registering MatrixBandPart (<function _MatrixBandPartGrad at 0x000001E47B50E280>) in gradient.
# Level 1:tensorflow:Registering EditDistance (None) in gradient.
# Level 1:tensorflow:Registering Fill (<function _FillGrad at 0x000001E47B50E430>) in gradient.
# Level 1:tensorflow:Registering ZerosLike (None) in gradient.
# Level 1:tensorflow:Registering OnesLike (None) in gradient.
# Level 1:tensorflow:Registering PreventGradient (<function _PreventGradientGrad at 0x000001E47B50E310>) in gradient.
# Level 1:tensorflow:Registering Gather (<function _GatherGrad at 0x000001E47B50E4C0>) in gradient.
# Level 1:tensorflow:Registering GatherV2 (<function _GatherV2Grad at 0x000001E47B50E700>) in gradient.
# Level 1:tensorflow:Registering GatherNd (<function _GatherNdGrad at 0x000001E47B50E790>) in gradient.
# Level 1:tensorflow:Registering ResourceGatherNd (<function _ResourceGatherNdGrad at 0x000001E47B50E8B0>) in gradient.
# Level 1:tensorflow:Registering CheckNumerics (<function _CheckNumericsGrad at 0x000001E47B50E5E0>) in gradient.
# Level 1:tensorflow:Registering CheckNumericsV2 (<function _CheckNumericsV2Grad at 0x000001E47B50E940>) in gradient.
# Level 1:tensorflow:Registering Identity (<function _IdGrad at 0x000001E47B50E9D0>) in gradient.
# Level 1:tensorflow:Registering PlaceholderWithDefault (<function _IdGrad at 0x000001E47B50E9D0>) in gradient.
# Level 1:tensorflow:Registering _EagerConst (<function _EagerConstGrad at 0x000001E47B50EAF0>) in gradient.
# Level 1:tensorflow:Registering RefIdentity (<function _RefIdGrad at 0x000001E47B50EA60>) in gradient.
# Level 1:tensorflow:Registering IdentityN (<function _IdNGrad at 0x000001E47B50EB80>) in gradient.
# Level 1:tensorflow:Registering StopGradient (None) in gradient.
# Level 1:tensorflow:Registering Reshape (<function _ReshapeGrad at 0x000001E47B50EC10>) in gradient.
# Level 1:tensorflow:Registering InvertPermutation (None) in gradient.
# Level 1:tensorflow:Registering ExpandDims (<function _ExpandDimsGrad at 0x000001E47B50ED30>) in gradient.
# Level 1:tensorflow:Registering Squeeze (<function _SqueezeGrad at 0x000001E47B50EE50>) in gradient.
# Level 1:tensorflow:Registering Transpose (<function _TransposeGrad at 0x000001E47B50E820>) in gradient.
# Level 1:tensorflow:Registering ConjugateTranspose (<function _ConjugateTransposeGrad at 0x000001E47B50EEE0>) in gradient.
# Level 1:tensorflow:Registering Shape (None) in gradient.
# Level 1:tensorflow:Registering ShapeN (None) in gradient.
# Level 1:tensorflow:Registering Rank (None) in gradient.
# Level 1:tensorflow:Registering Size (None) in gradient.
# Level 1:tensorflow:Registering Tile (<function _TileGrad at 0x000001E47B50EF70>) in gradient.
# Level 1:tensorflow:Registering BroadcastGradientArgs (None) in gradient.
# Level 1:tensorflow:Registering Pad (<function _PadGrad at 0x000001E47B50EDC0>) in gradient.
# Level 1:tensorflow:Registering PadV2 (<function _PadGrad at 0x000001E47B50EDC0>) in gradient.
# Level 1:tensorflow:Registering ReverseSequence (<function _ReverseSequenceGrad at 0x000001E47B516040>) in gradient.
# Level 1:tensorflow:Registering Reverse (<function _ReverseGrad at 0x000001E47B516280>) in gradient.
# Level 1:tensorflow:Registering ReverseV2 (<function _ReverseV2Grad at 0x000001E47B5160D0>) in gradient.
# Level 1:tensorflow:Registering SpaceToBatch (<function _SpaceToBatchGrad at 0x000001E47B5161F0>) in gradient.
# Level 1:tensorflow:Registering SpaceToBatchND (<function _SpaceToBatchNDGrad at 0x000001E47B516160>) in gradient.
# Level 1:tensorflow:Registering BatchToSpace (<function _BatchToSpaceGrad at 0x000001E47B516310>) in gradient.
# Level 1:tensorflow:Registering BatchToSpaceND (<function _BatchToSpaceNDGrad at 0x000001E47B516430>) in gradient.
# Level 1:tensorflow:Registering SpaceToDepth (<function _SpaceToDepthGrad at 0x000001E47B516550>) in gradient.
# Level 1:tensorflow:Registering DepthToSpace (<function _DepthToSpaceGrad at 0x000001E47B5163A0>) in gradient.
# Level 1:tensorflow:Registering OneHot (None) in gradient.
# Level 1:tensorflow:Registering MirrorPad (<function _MirrorPadGrad at 0x000001E47B5164C0>) in gradient.
# Level 1:tensorflow:Registering MirrorPadGrad (<function _MirrorPadGradGrad at 0x000001E47B516670>) in gradient.
# Level 1:tensorflow:Registering QuantizeAndDequantize (<function _QuantizeAndDequantizeGrad at 0x000001E47B516700>) in gradient.
# Level 1:tensorflow:Registering QuantizeAndDequantizeV2 (<function _QuantizeAndDequantizeV2Grad at 0x000001E47B516790>) in gradient.
# Level 1:tensorflow:Registering QuantizeAndDequantizeV3 (<function _QuantizeAndDequantizeV3Grad at 0x000001E47B5165E0>) in gradient.
# Level 1:tensorflow:Registering ExtractImagePatches (<function _ExtractImagePatchesGrad at 0x000001E47B516820>) in gradient.
# Level 1:tensorflow:Registering ExtractVolumePatches (<function _ExtractVolumePatchesGrad at 0x000001E47B5168B0>) in gradient.
# Level 1:tensorflow:Registering ScatterNd (<function _ScatterNdGrad at 0x000001E47B516940>) in gradient.
# Level 1:tensorflow:Registering TensorScatterUpdate (<function _TensorScatterUpdateGrad at 0x000001E47B5169D0>) in gradient.
# Level 1:tensorflow:Registering TensorScatterAdd (<function _TensorScatterAddGrad at 0x000001E47B516B80>) in gradient.
# Level 1:tensorflow:Registering TensorScatterMax (<function _TensorScatterMaxGrad at 0x000001E47B516AF0>) in gradient.
# Level 1:tensorflow:Registering TensorScatterMin (<function _TensorScatterMinGrad at 0x000001E47B516D30>) in gradient.
# Level 1:tensorflow:Registering TensorScatterSub (<function _TensorScatterSubGrad at 0x000001E47B516E50>) in gradient.
# Level 1:tensorflow:Registering ScatterNdNonAliasingAdd (<function _ScatterNdNonAliasingAddGrad at 0x000001E47B516A60>) in gradient.
# Level 1:tensorflow:Registering BroadcastTo (<function _BroadcastToGrad at 0x000001E47B516CA0>) in gradient.
# Level 1:tensorflow:Registering Switch (<function _SwitchGrad at 0x000001E47B51A040>) in gradient.
# Level 1:tensorflow:Registering RefSwitch (<function _SwitchGrad at 0x000001E47B51A040>) in gradient.
# Level 1:tensorflow:Registering Merge (<function _MergeGrad at 0x000001E47B51A280>) in gradient.
# Level 1:tensorflow:Registering RefMerge (<function _RefMergeGrad at 0x000001E47B51A3A0>) in gradient.
# Level 1:tensorflow:Registering Exit (<function _ExitGrad at 0x000001E47B51A0D0>) in gradient.
# Level 1:tensorflow:Registering RefExit (<function _ExitGrad at 0x000001E47B51A0D0>) in gradient.
# Level 1:tensorflow:Registering NextIteration (<function _NextIterationGrad at 0x000001E47B51A550>) in gradient.
# Level 1:tensorflow:Registering RefNextIteration (<function _RefNextIterationGrad at 0x000001E47B51A4C0>) in gradient.
# Level 1:tensorflow:Registering Enter (<function _EnterGrad at 0x000001E47B51A310>) in gradient.
# Level 1:tensorflow:Registering RefEnter (<function _RefEnterGrad at 0x000001E47B51A670>) in gradient.
# Level 1:tensorflow:Registering LoopCond (<function _LoopCondGrad at 0x000001E47B51A700>) in gradient.
# Level 1:tensorflow:Registering ResizeNearestNeighbor (<function _ResizeNearestNeighborGrad at 0x000001E47B51A5E0>) in gradient.
# Level 1:tensorflow:Registering ResizeBilinear (<function _ResizeBilinearGrad at 0x000001E47B51AE50>) in gradient.
# Level 1:tensorflow:Registering ScaleAndTranslate (<function _ScaleAndTranslateGrad at 0x000001E47B51A790>) in gradient.
# Level 1:tensorflow:Registering ResizeBicubic (<function _ResizeBicubicGrad at 0x000001E47B51AF70>) in gradient.
# Level 1:tensorflow:Registering CropAndResize (<function _CropAndResizeGrad at 0x000001E47B52C0D0>) in gradient.
# Level 1:tensorflow:Registering RGBToHSV (<function _RGBToHSVGrad at 0x000001E47B52C1F0>) in gradient.
# Level 1:tensorflow:Registering MatrixInverse (<function _MatrixInverseGrad at 0x000001E47B52CCA0>) in gradient.
# Level 1:tensorflow:Registering Einsum (<function _EinsumGrad at 0x000001E47B5579D0>) in gradient.
# Level 1:tensorflow:Registering MatrixDeterminant (<function _MatrixDeterminantGrad at 0x000001E47B557A60>) in gradient.
# Level 1:tensorflow:Registering MatrixSquareRoot (<function _MatrixSquareRootGrad at 0x000001E47B52C310>) in gradient.
# Level 1:tensorflow:Registering LogMatrixDeterminant (<function _LogMatrixDeterminantGrad at 0x000001E47B557AF0>) in gradient.
# Level 1:tensorflow:Registering Cholesky (<function _CholeskyGrad at 0x000001E47B557B80>) in gradient.
# Level 1:tensorflow:Registering Qr (<function _QrGrad at 0x000001E47B557CA0>) in gradient.
# Level 1:tensorflow:Registering MatrixSolve (<function _MatrixSolveGrad at 0x000001E47B557C10>) in gradient.
# Level 1:tensorflow:Registering MatrixSolveLs (<function _MatrixSolveLsGrad at 0x000001E47B557E50>) in gradient.
# Level 1:tensorflow:Registering BandedTriangularSolve (<function _BandedTriangularSolveGrad at 0x000001E47B557D30>) in gradient.
# Level 1:tensorflow:Registering MatrixTriangularSolve (<function _MatrixTriangularSolveGrad at 0x000001E47B557DC0>) in gradient.
# Level 1:tensorflow:Registering Eig (<function _EigGrad at 0x000001E47B56A040>) in gradient.
# Level 1:tensorflow:Registering SelfAdjointEigV2 (<function _SelfAdjointEigV2Grad at 0x000001E47B557F70>) in gradient.
# Level 1:tensorflow:Registering Svd (<function _SvdGrad at 0x000001E47B56A0D0>) in gradient.
# Level 1:tensorflow:Registering TridiagonalMatMul (<function _TridiagonalMatMulGrad at 0x000001E47B56A280>) in gradient.
# Level 1:tensorflow:Registering TridiagonalSolve (<function _TridiagonalSolveGrad at 0x000001E47B56A310>) in gradient.
# Level 1:tensorflow:Registering Roll (<function _RollGrad at 0x000001E47B52CC10>) in gradient.
# Level 1:tensorflow:Registering ArgMax (<function _ArgMaxGrad at 0x000001E47B57AA60>) in gradient.
# Level 1:tensorflow:Registering ArgMin (<function _ArgMinGrad at 0x000001E47B58FC10>) in gradient.
# Level 1:tensorflow:Registering EuclideanNorm (<function _EuclideanNormGrad at 0x000001E47B56A430>) in gradient.
# Level 1:tensorflow:Registering Sum (<function _SumGrad at 0x000001E47B58FE50>) in gradient.
# Level 1:tensorflow:Registering Max (<function _MaxGrad at 0x000001E47B58FEE0>) in gradient.
# Level 1:tensorflow:Registering Min (<function _MinGrad at 0x000001E47B58FF70>) in gradient.
# Level 1:tensorflow:Registering Mean (<function _MeanGrad at 0x000001E47B5B0040>) in gradient.
# Level 1:tensorflow:Registering Prod (<function _ProdGrad at 0x000001E47B5B0160>) in gradient.
# Level 1:tensorflow:Registering SegmentSum (<function _SegmentSumGrad at 0x000001E47B5B01F0>) in gradient.
# Level 1:tensorflow:Registering SegmentMean (<function _SegmentMeanGrad at 0x000001E47B5B0310>) in gradient.
# Level 1:tensorflow:Registering SparseSegmentSum (<function _SparseSegmentSumGrad at 0x000001E47B5B0280>) in gradient.
# Level 1:tensorflow:Registering SparseSegmentSumWithNumSegments (<function _SparseSegmentSumWithNumSegmentsGrad at 0x000001E47B5B00D0>) in gradient.
# Level 1:tensorflow:Registering SparseSegmentMean (<function _SparseSegmentMeanGrad at 0x000001E47B5B03A0>) in gradient.
# Level 1:tensorflow:Registering SparseSegmentMeanWithNumSegments (<function _SparseSegmentMeanWithNumSegmentsGrad at 0x000001E47B5B0430>) in gradient.
# Level 1:tensorflow:Registering SparseSegmentSqrtN (<function _SparseSegmentSqrtNGrad at 0x000001E47B5B05E0>) in gradient.
# Level 1:tensorflow:Registering SparseSegmentSqrtNWithNumSegments (<function _SparseSegmentSqrtNWithNumSegmentsGrad at 0x000001E47B5B04C0>) in gradient.
# Level 1:tensorflow:Registering SegmentMin (<function _SegmentMinGrad at 0x000001E47B5B0700>) in gradient.
# Level 1:tensorflow:Registering SegmentMax (<function _SegmentMaxGrad at 0x000001E47B5B0670>) in gradient.
# Level 1:tensorflow:Registering SegmentProd (<function _SegmentProdGrad at 0x000001E47B5B0790>) in gradient.
# Level 1:tensorflow:Registering UnsortedSegmentSum (<function _UnsortedSegmentSumGrad at 0x000001E47B5B09D0>) in gradient.
# Level 1:tensorflow:Registering UnsortedSegmentMax (<function _UnsortedSegmentMaxGrad at 0x000001E47B5B08B0>) in gradient.
# Level 1:tensorflow:Registering UnsortedSegmentMin (<function _UnsortedSegmentMinGrad at 0x000001E47B5B0AF0>) in gradient.
# Level 1:tensorflow:Registering UnsortedSegmentProd (<function _UnsortedSegmentProdGrad at 0x000001E47B5B0A60>) in gradient.
# Level 1:tensorflow:Registering Abs (<function _AbsGrad at 0x000001E47B5B0B80>) in gradient.
# Level 1:tensorflow:Registering Neg (<function _NegGrad at 0x000001E47B5B0CA0>) in gradient.
# Level 1:tensorflow:Registering Inv (<function _InvGrad at 0x000001E47B5B0EE0>) in gradient.
# Level 1:tensorflow:Registering Reciprocal (<function _ReciprocalGrad at 0x000001E47B5B0C10>) in gradient.
# Level 1:tensorflow:Registering InvGrad (<function _InvGradGrad at 0x000001E47B5B0E50>) in gradient.
# Level 1:tensorflow:Registering ReciprocalGrad (<function _ReciprocalGradGrad at 0x000001E47B5B0DC0>) in gradient.
# Level 1:tensorflow:Registering Square (<function _SquareGrad at 0x000001E47B5B0D30>) in gradient.
# Level 1:tensorflow:Registering Sqrt (<function _SqrtGrad at 0x000001E47B5B0F70>) in gradient.
# Level 1:tensorflow:Registering SqrtGrad (<function _SqrtGradGrad at 0x000001E47B5B70D0>) in gradient.
# Level 1:tensorflow:Registering Rsqrt (<function _RsqrtGrad at 0x000001E47B5B7040>) in gradient.
# Level 1:tensorflow:Registering RsqrtGrad (<function _RsqrtGradGrad at 0x000001E47B5B7160>) in gradient.
# Level 1:tensorflow:Registering Exp (<function _ExpGrad at 0x000001E47B5B7280>) in gradient.
# Level 1:tensorflow:Registering Expm1 (<function _Expm1Grad at 0x000001E47B5B71F0>) in gradient.
# Level 1:tensorflow:Registering Log (<function _LogGrad at 0x000001E47B5B7310>) in gradient.
# Level 1:tensorflow:Registering Log1p (<function _Log1pGrad at 0x000001E47B5B7430>) in gradient.
# Level 1:tensorflow:Registering Xlogy (<function _XLogyGrad at 0x000001E47B5B75E0>) in gradient.
# Level 1:tensorflow:Registering Xlog1py (<function _XLog1pyGrad at 0x000001E47B5B7550>) in gradient.
# Level 1:tensorflow:Registering Xdivy (<function _XDivyGrad at 0x000001E47B5B74C0>) in gradient.
# Level 1:tensorflow:Registering Sinh (<function _SinhGrad at 0x000001E47B5B7670>) in gradient.
# Level 1:tensorflow:Registering Cosh (<function _CoshGrad at 0x000001E47B5B7700>) in gradient.
# Level 1:tensorflow:Registering Tanh (<function _TanhGrad at 0x000001E47B5B73A0>) in gradient.
# Level 1:tensorflow:Registering Asinh (<function _AsinhGrad at 0x000001E47B5B7820>) in gradient.
# Level 1:tensorflow:Registering Acosh (<function _AcoshGrad at 0x000001E47B5B7790>) in gradient.
# Level 1:tensorflow:Registering Atanh (<function _AtanhGrad at 0x000001E47B5B79D0>) in gradient.
# Level 1:tensorflow:Registering TanhGrad (<function _TanhGradGrad at 0x000001E47B5B7940>) in gradient.
# Level 1:tensorflow:Registering Erf (<function _ErfGrad at 0x000001E47B5B78B0>) in gradient.
# Level 1:tensorflow:Registering Erfc (<function _ErfcGrad at 0x000001E47B5B7C10>) in gradient.
# Level 1:tensorflow:Registering Erfinv (<function _ErfinvGrad at 0x000001E47B5B7A60>) in gradient.
# Level 1:tensorflow:Registering Ndtri (<function _NdtriGrad at 0x000001E47B5B7D30>) in gradient.
# Level 1:tensorflow:Registering Lgamma (<function _LgammaGrad at 0x000001E47B5B7CA0>) in gradient.
# Level 1:tensorflow:Registering Digamma (<function _DigammaGrad at 0x000001E47B5B7B80>) in gradient.
# Level 1:tensorflow:Registering Dawsn (<function _DawsnGrad at 0x000001E47B5B7AF0>) in gradient.
# Level 1:tensorflow:Registering Expint (<function _ExpintGrad at 0x000001E47B5B7DC0>) in gradient.
# Level 1:tensorflow:Registering FresnelCos (<function _FresnelCosGrad at 0x000001E47B5B7E50>) in gradient.
# Level 1:tensorflow:Registering FresnelSin (<function _FresnelSinGrad at 0x000001E47B5B7F70>) in gradient.
# Level 1:tensorflow:Registering Spence (<function _SpenceGrad at 0x000001E47B5B7EE0>) in gradient.
# Level 1:tensorflow:Registering BesselI0 (<function _BesselI0Grad at 0x000001E47B5BC040>) in gradient.
# Level 1:tensorflow:Registering BesselI0e (<function _BesselI0eGrad at 0x000001E47B5BC160>) in gradient.
# Level 1:tensorflow:Registering BesselI1 (<function _BesselI1Grad at 0x000001E47B5BC280>) in gradient.
# Level 1:tensorflow:Registering BesselI1e (<function _BesselI1eGrad at 0x000001E47B5BC0D0>) in gradient.
# Level 1:tensorflow:Registering BesselK0 (<function _BesselK0Grad at 0x000001E47B5BC1F0>) in gradient.
# Level 1:tensorflow:Registering BesselK0e (<function _BesselK0eGrad at 0x000001E47B5BC430>) in gradient.
# Level 1:tensorflow:Registering BesselK1 (<function _BesselK1Grad at 0x000001E47B5BC3A0>) in gradient.
# Level 1:tensorflow:Registering BesselK1e (<function _BesselK1eGrad at 0x000001E47B5BC4C0>) in gradient.
# Level 1:tensorflow:Registering BesselJ0 (<function _BesselJ0Grad at 0x000001E47B5BC5E0>) in gradient.
# Level 1:tensorflow:Registering BesselJ1 (<function _BesselJ1Grad at 0x000001E47B5BC310>) in gradient.
# Level 1:tensorflow:Registering BesselY0 (<function _BesselY0Grad at 0x000001E47B5BC550>) in gradient.
# Level 1:tensorflow:Registering BesselY1 (<function _BesselY1Grad at 0x000001E47B5BC670>) in gradient.
# Level 1:tensorflow:Registering Igamma (<function _IgammaGrad at 0x000001E47B5BC700>) in gradient.
# Level 1:tensorflow:Registering Igammac (<function _IgammacGrad at 0x000001E47B5BC820>) in gradient.
# Level 1:tensorflow:Registering Betainc (<function _BetaincGrad at 0x000001E47B5BC790>) in gradient.
# Level 1:tensorflow:Registering Zeta (<function _ZetaGrad at 0x000001E47B5BC8B0>) in gradient.
# Level 1:tensorflow:Registering Polygamma (<function _PolygammaGrad at 0x000001E47B5BC940>) in gradient.
# Level 1:tensorflow:Registering Sigmoid (<function _SigmoidGrad at 0x000001E47B5BCAF0>) in gradient.
# Level 1:tensorflow:Registering SigmoidGrad (<function _SigmoidGradGrad at 0x000001E47B5BC9D0>) in gradient.
# Level 1:tensorflow:Registering Sign (<function _SignGrad at 0x000001E47B5BCA60>) in gradient.
# Level 1:tensorflow:Registering Sin (<function _SinGrad at 0x000001E47B5BCB80>) in gradient.
# Level 1:tensorflow:Registering Cos (<function _CosGrad at 0x000001E47B5BCD30>) in gradient.
# Level 1:tensorflow:Registering Tan (<function _TanGrad at 0x000001E47B5BCC10>) in gradient.
# Level 1:tensorflow:Registering Asin (<function _AsinGrad at 0x000001E47B5BCDC0>) in gradient.
# Level 1:tensorflow:Registering Acos (<function _AcosGrad at 0x000001E47B5BCE50>) in gradient.
# Level 1:tensorflow:Registering Atan (<function _AtanGrad at 0x000001E47B5BCEE0>) in gradient.
# Level 1:tensorflow:Registering Atan2 (<function _Atan2Grad at 0x000001E47B5BCCA0>) in gradient.
# Level 1:tensorflow:Registering AddN (<function _AddNGrad at 0x000001E47B5BCF70>) in gradient.
# Level 1:tensorflow:Registering AddV2 (<function _AddGrad at 0x000001E47B5BF040>) in gradient.
# Level 1:tensorflow:Registering Add (<function _AddGrad at 0x000001E47B5BF040>) in gradient.
# Level 1:tensorflow:Registering Sub (<function _SubGrad at 0x000001E47B5BF160>) in gradient.
# Level 1:tensorflow:Registering Mul (<function _MulGrad at 0x000001E47B5BF310>) in gradient.
# Level 1:tensorflow:Registering MulNoNan (<function _MulNoNanGrad at 0x000001E47B5BF3A0>) in gradient.
# Level 1:tensorflow:Registering Div (<function _DivGrad at 0x000001E47B5BF430>) in gradient.
# Level 1:tensorflow:Registering FloorDiv (<function _FloorDivGrad at 0x000001E47B5BF280>) in gradient.
# Level 1:tensorflow:Registering FloorMod (<function _FloorModGrad at 0x000001E47B5BF550>) in gradient.
# Level 1:tensorflow:Registering TruncateDiv (<function _TruncateDivGrad at 0x000001E47B5BF4C0>) in gradient.
# Level 1:tensorflow:Registering RealDiv (<function _RealDivGrad at 0x000001E47B5BF5E0>) in gradient.
# Level 1:tensorflow:Registering DivNoNan (<function _DivNoNanGrad at 0x000001E47B5BF1F0>) in gradient.
# Level 1:tensorflow:Registering Pow (<function _PowGrad at 0x000001E47B5BF820>) in gradient.
# Level 1:tensorflow:Registering Maximum (<function _MaximumGrad at 0x000001E47B5BF670>) in gradient.
# Level 1:tensorflow:Registering Minimum (<function _MinimumGrad at 0x000001E47B5BF940>) in gradient.
# Level 1:tensorflow:Registering SquaredDifference (<function _SquaredDifferenceGrad at 0x000001E47B5BF8B0>) in gradient.
# Level 1:tensorflow:Registering Less (None) in gradient.
# Level 1:tensorflow:Registering LessEqual (None) in gradient.
# Level 1:tensorflow:Registering Greater (None) in gradient.
# Level 1:tensorflow:Registering GreaterEqual (None) in gradient.
# Level 1:tensorflow:Registering Equal (None) in gradient.
# Level 1:tensorflow:Registering ApproximateEqual (None) in gradient.
# Level 1:tensorflow:Registering NotEqual (None) in gradient.
# Level 1:tensorflow:Registering LogicalAnd (None) in gradient.
# Level 1:tensorflow:Registering LogicalOr (None) in gradient.
# Level 1:tensorflow:Registering LogicalNot (None) in gradient.
# Level 1:tensorflow:Registering Select (<function _SelectGrad at 0x000001E47B5BFC10>) in gradient.
# Level 1:tensorflow:Registering SelectV2 (<function _SelectGradV2 at 0x000001E47B5BF9D0>) in gradient.
# Level 1:tensorflow:Registering MatMul (<function _MatMulGrad at 0x000001E47B5BFD30>) in gradient.
# Level 1:tensorflow:Registering SparseMatMul (<function _SparseMatMulGrad at 0x000001E47B5BFAF0>) in gradient.
# Level 1:tensorflow:Registering Floor (<function _FloorGrad at 0x000001E47B5BFDC0>) in gradient.
# Level 1:tensorflow:Registering Ceil (<function _CeilGrad at 0x000001E47B5BFE50>) in gradient.
# Level 1:tensorflow:Registering Round (<function _RoundGrad at 0x000001E47B5BFF70>) in gradient.
# Level 1:tensorflow:Registering Rint (<function _RintGrad at 0x000001E47B5BFA60>) in gradient.
# Level 1:tensorflow:Registering BatchMatMul (<function _BatchMatMul at 0x000001E47B5BFEE0>) in gradient.
# Level 1:tensorflow:Registering BatchMatMulV3 (<function _BatchMatMulV2 at 0x000001E47B5C30D0>) in gradient.
# Level 1:tensorflow:Registering BatchMatMulV2 (<function _BatchMatMulV2 at 0x000001E47B5C30D0>) in gradient.
# Level 1:tensorflow:Registering Range (None) in gradient.
# Level 1:tensorflow:Registering LinSpace (None) in gradient.
# Level 1:tensorflow:Registering Complex (<function _ComplexGrad at 0x000001E47B5C3160>) in gradient.
# Level 1:tensorflow:Registering Real (<function _RealGrad at 0x000001E47B5C3040>) in gradient.
# Level 1:tensorflow:Registering Imag (<function _ImagGrad at 0x000001E47B5C3280>) in gradient.
# Level 1:tensorflow:Registering Angle (<function _AngleGrad at 0x000001E47B5C31F0>) in gradient.
# Level 1:tensorflow:Registering Conj (<function _ConjGrad at 0x000001E47B5C34C0>) in gradient.
# ...
# Level 1:tensorflow:Registering TensorArray (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayGrad (None) in gradient.
# Level 1:tensorflow:Registering TensorArraySize (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayClose (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayV2 (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayGradV2 (None) in gradient.
# Level 1:tensorflow:Registering TensorArraySizeV2 (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayCloseV2 (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayV3 (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayGradV3 (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayGradWithShape (None) in gradient.
# Level 1:tensorflow:Registering TensorArraySizeV3 (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayCloseV3 (None) in gradient.
# Level 1:tensorflow:Registering TensorArrayReadV3 (<function _TensorArrayReadGrad at 0x000001E47B7F01F0>) in gradient.
# Level 1:tensorflow:Registering TensorArrayReadV2 (<function _TensorArrayReadGrad at 0x000001E47B7F01F0>) in gradient.
# Level 1:tensorflow:Registering TensorArrayRead (<function _TensorArrayReadGrad at 0x000001E47B7F01F0>) in gradient.
# Level 1:tensorflow:Registering TensorArrayWriteV3 (<function _TensorArrayWriteGrad at 0x000001E47B7E4E50>) in gradient.
# Level 1:tensorflow:Registering TensorArrayWriteV2 (<function _TensorArrayWriteGrad at 0x000001E47B7E4E50>) in gradient.
# Level 1:tensorflow:Registering TensorArrayWrite (<function _TensorArrayWriteGrad at 0x000001E47B7E4E50>) in gradient.
# Level 1:tensorflow:Registering TensorArrayGatherV3 (<function _TensorArrayGatherGrad at 0x000001E47B7F0160>) in gradient.
# Level 1:tensorflow:Registering TensorArrayGatherV2 (<function _TensorArrayGatherGrad at 0x000001E47B7F0160>) in gradient.
# Level 1:tensorflow:Registering TensorArrayGather (<function _TensorArrayGatherGrad at 0x000001E47B7F0160>) in gradient.
# Level 1:tensorflow:Registering TensorArrayScatterV3 (<function _TensorArrayScatterGrad at 0x000001E47B7F0310>) in gradient.
# Level 1:tensorflow:Registering TensorArrayScatterV2 (<function _TensorArrayScatterGrad at 0x000001E47B7F0310>) in gradient.
# Level 1:tensorflow:Registering TensorArrayScatter (<function _TensorArrayScatterGrad at 0x000001E47B7F0310>) in gradient.
# Level 1:tensorflow:Registering TensorArrayConcatV3 (<function _TensorArrayConcatGrad at 0x000001E47B7F0430>) in gradient.
# Level 1:tensorflow:Registering TensorArrayConcatV2 (<function _TensorArrayConcatGrad at 0x000001E47B7F0430>) in gradient.
# Level 1:tensorflow:Registering TensorArrayConcat (<function _TensorArrayConcatGrad at 0x000001E47B7F0430>) in gradient.
# Level 1:tensorflow:Registering TensorArraySplitV3 (<function _TensorArraySplitGrad at 0x000001E47B7F04C0>) in gradient.
# Level 1:tensorflow:Registering TensorArraySplitV2 (<function _TensorArraySplitGrad at 0x000001E47B7F04C0>) in gradient.
# Level 1:tensorflow:Registering TensorArraySplit (<function _TensorArraySplitGrad at 0x000001E47B7F04C0>) in gradient.
# Level 1:tensorflow:Registering NcclAllReduce (<function _all_sum_grad at 0x000001E47B943040>) in gradient.
# Level 1:tensorflow:Registering NcclReduce (<function _reduce_sum_grad at 0x000001E47B943670>) in gradient.
# Level 1:tensorflow:Registering NcclBroadcast (<function _broadcast_grad at 0x000001E47B943790>) in gradient.
# DEBUG:tensorflow:Falling back to TensorFlow client; we recommended you install the Cloud TPU client directly with pip install cloud-tpu-client.
# Level 1:tensorflow:Registering CudnnRNN (<function _cudnn_rnn_backward at 0x000001E47BCEAC10>) in gradient.
# Level 1:tensorflow:Registering CudnnRNNV2 (<function _cudnn_rnn_backward_v2 at 0x000001E47BD190D0>) in gradient.
# Level 1:tensorflow:Registering CudnnRNNV3 (<function _cudnn_rnn_backwardv3 at 0x000001E47BD19040>) in gradient.
# Level 1:tensorflow:Registering BlockLSTM (<function _block_lstm_grad at 0x000001E47BD19280>) in gradient.
# Level 1:tensorflow:Registering BlockLSTMV2 (<function _block_lstm_grad at 0x000001E47BD19280>) in gradient.
# Level 1:tensorflow:Registering SparseAddGrad (None) in gradient.
# Level 1:tensorflow:Registering SparseConcat (None) in gradient.
# Level 1:tensorflow:Registering SparseReorder (<function _SparseReorderGrad at 0x000001E47BD2F940>) in gradient.
# Level 1:tensorflow:Registering SparseAdd (<function _SparseAddGrad at 0x000001E47BD3C1F0>) in gradient.
# Level 1:tensorflow:Registering SparseTensorDenseAdd (<function _SparseTensorDenseAddGrad at 0x000001E47BD3C280>) in gradient.
# Level 1:tensorflow:Registering SparseReduceSum (<function _SparseReduceSumGrad at 0x000001E47BD3C310>) in gradient.
# Level 1:tensorflow:Registering SparseSlice (<function _SparseSliceGrad at 0x000001E47BD3C3A0>) in gradient.
# Level 1:tensorflow:Registering SparseTensorDenseMatMul (<function _SparseTensorDenseMatMulGrad at 0x000001E47BD3C430>) in gradient.
# Level 1:tensorflow:Registering SparseDenseCwiseAdd (<function _SparseDenseCwiseAddGrad at 0x000001E47BD3C4C0>) in gradient.
# Level 1:tensorflow:Registering SparseDenseCwiseMul (<function _SparseDenseCwiseMulGrad at 0x000001E47BD3C670>) in gradient.
# Level 1:tensorflow:Registering SparseDenseCwiseDiv (<function _SparseDenseCwiseDivGrad at 0x000001E47BD3C5E0>) in gradient.
# Level 1:tensorflow:Registering SparseSoftmax (<function _SparseSoftmaxGrad at 0x000001E47BD3C700>) in gradient.
# Level 1:tensorflow:Registering SparseSparseMaximum (<function _SparseSparseMaximumGrad at 0x000001E47BD3C790>) in gradient.
# Level 1:tensorflow:Registering SparseSparseMinimum (<function _SparseSparseMinimumGrad at 0x000001E47BD3C820>) in gradient.
# Level 1:tensorflow:Registering SparseFillEmptyRows (<function _SparseFillEmptyRowsGrad at 0x000001E47BD3C8B0>) in gradient.
# Level 1:tensorflow:Registering SparseToDense (<function _SparseToDenseGrad at 0x000001E47BD3C940>) in gradient.
# Level 1:tensorflow:Registering Assign (None) in gradient.
# Level 1:tensorflow:Registering AssignAdd (None) in gradient.
# Level 1:tensorflow:Registering AssignSub (None) in gradient.
# Level 1:tensorflow:Registering ScatterAdd (None) in gradient.
# Level 1:tensorflow:Registering ScatterSub (None) in gradient.
# Level 1:tensorflow:Registering ScatterMul (None) in gradient.
# Level 1:tensorflow:Registering ScatterDiv (None) in gradient.
# Level 1:tensorflow:Registering ScatterNdUpdate (None) in gradient.
# Level 1:tensorflow:Registering ScatterNdAdd (None) in gradient.
# Level 1:tensorflow:Registering ScatterNdSub (None) in gradient.
# Level 1:tensorflow:Registering ScatterNdMul (None) in gradient.
# Level 1:tensorflow:Registering ScatterNdDiv (None) in gradient.
# Level 1:tensorflow:Registering DecodeProtoV2 (None) in gradient.
# Level 1:tensorflow:Registering EncodeProto (None) in gradient.
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# DEBUG:h5py._conv:Creating converter from 7 to 5
# DEBUG:h5py._conv:Creating converter from 5 to 7
# Level 1:tensorflow:Registering If (<function _IfGrad at 0x000001E47F943DC0>) in gradient.
# Level 1:tensorflow:Registering StatelessIf (<function _IfGrad at 0x000001E47F943DC0>) in gradient.
# Level 1:tensorflow:Registering StatelessCase (<function _CaseGrad at 0x000001E47F96ADC0>) in gradient.
# Level 1:tensorflow:Registering Case (<function _CaseGrad at 0x000001E47F96ADC0>) in gradient.
# Level 1:tensorflow:Registering While (<function _WhileGrad at 0x000001E47F9AF8B0>) in gradient.
# Level 1:tensorflow:Registering StatelessWhile (<function _WhileGrad at 0x000001E47F9AF8B0>) in gradient.
# Level 1:tensorflow:Registering FFT (<function _fft_grad at 0x000001E47FAA2670>) in gradient.
# Level 1:tensorflow:Registering IFFT (<function _ifft_grad at 0x000001E47FAAF160>) in gradient.
# Level 1:tensorflow:Registering FFT2D (<function _fft2d_grad at 0x000001E47FA8D820>) in gradient.
# Level 1:tensorflow:Registering IFFT2D (<function _ifft2d_grad at 0x000001E47FAAF310>) in gradient.
# Level 1:tensorflow:Registering FFT3D (<function _fft3d_grad at 0x000001E47FAAF280>) in gradient.
# Level 1:tensorflow:Registering IFFT3D (<function _ifft3d_grad at 0x000001E47FAAF1F0>) in gradient.
# Level 1:tensorflow:Registering RFFT (<function _rfft_grad_helper.<locals>._grad at 0x000001E47FAAF790>) in gradient.
# Level 1:tensorflow:Registering IRFFT (<function _irfft_grad_helper.<locals>._grad at 0x000001E47FAAF430>) in gradient.
# Level 1:tensorflow:Registering RFFT2D (<function _rfft_grad_helper.<locals>._grad at 0x000001E47FAAF940>) in gradient.
# Level 1:tensorflow:Registering IRFFT2D (<function _irfft_grad_helper.<locals>._grad at 0x000001E47FAAF9D0>) in gradient.
# Level 1:tensorflow:Registering DenseToCSRSparseMatrix (<function _DenseToCSRSparseMatrixGrad at 0x000001E47FB1B1F0>) in gradient.
# Level 1:tensorflow:Registering CSRSparseMatrixToDense (<function _CSRSparseMatrixToDenseGrad at 0x000001E47FB3A9D0>) in gradient.
# Level 1:tensorflow:Registering SparseTensorToCSRSparseMatrix (<function _SparseTensorToCSRSparseMatrixGrad at 0x000001E47FB3AAF0>) in gradient.
# Level 1:tensorflow:Registering CSRSparseMatrixToSparseTensor (<function _CSRSparseMatrixToSparseTensorGrad at 0x000001E47FAE2D30>) in gradient.
# Level 1:tensorflow:Registering SparseMatrixNNZ (None) in gradient.
# Level 1:tensorflow:Registering SparseMatrixZeros (None) in gradient.
# Level 1:tensorflow:Registering SparseMatrixAdd (<function _SparseMatrixAddGrad at 0x000001E47FB3AA60>) in gradient.
# Level 1:tensorflow:Registering SparseMatrixTranspose (<function _SparseMatrixTransposeGrad at 0x000001E47FB3ADC0>) in gradient.
# Level 1:tensorflow:Registering SparseMatrixSoftmax (<function _SparseMatrixSoftmaxGrad at 0x000001E47FB3AD30>) in gradient.
# Level 1:tensorflow:Registering SparseMatrixMatMul (<function _SparseMatrixMatMulGrad at 0x000001E47FB3AE50>) in gradient.
# Level 1:tensorflow:Registering SparseMatrixSparseMatMul (<function _SparseMatrixSparseMatMulGrad at 0x000001E47FB3AEE0>) in gradient.
# Level 1:tensorflow:Registering SparseMatrixMul (<function _SparseMatrixMulGrad at 0x000001E47FB3AF70>) in gradient.
# Level 1:tensorflow:Registering RaggedTensorToTensor (<function _ragged_tensor_to_tensor_grad at 0x000001E47FB58160>) in gradient.
# Level 1:tensorflow:Registering RaggedTensorFromVariant (<function _ragged_tensor_from_variant_grad at 0x000001E47FB584C0>) in gradient.
# Level 1:tensorflow:Registering RaggedTensorToVariant (<function _ragged_tensor_to_variant_grad at 0x000001E47FB581F0>) in gradient.
# Level 1:tensorflow:Registering Reciprocal,flops (<function _reciprocal_flops at 0x000001E47FBCF280>) in statistical functions.
# Level 1:tensorflow:Registering Square,flops (<function _square_flops at 0x000001E47FBCFAF0>) in statistical functions.
# Level 1:tensorflow:Registering Rsqrt,flops (<function _rsqrt_flops at 0x000001E47FBCFB80>) in statistical functions.
# Level 1:tensorflow:Registering Log,flops (<function _log_flops at 0x000001E47FBAA4C0>) in statistical functions.
# Level 1:tensorflow:Registering Neg,flops (<function _neg_flops at 0x000001E47FBCFC10>) in statistical functions.
# Level 1:tensorflow:Registering AssignSub,flops (<function _assign_sub_flops at 0x000001E47FBCFD30>) in statistical functions.
# Level 1:tensorflow:Registering AssignAdd,flops (<function _assign_add_flops at 0x000001E47FBCFDC0>) in statistical functions.
# Level 1:tensorflow:Registering L2Loss,flops (<function _l2_loss_flops at 0x000001E47FBCFCA0>) in statistical functions.
# Level 1:tensorflow:Registering Softmax,flops (<function _softmax_flops at 0x000001E47FBCFF70>) in statistical functions.
# Level 1:tensorflow:Registering Add,flops (<function _add_flops at 0x000001E47FBDD040>) in statistical functions.
# Level 1:tensorflow:Registering Sub,flops (<function _sub_flops at 0x000001E47FBCFEE0>) in statistical functions.
# Level 1:tensorflow:Registering Mul,flops (<function _mul_flops at 0x000001E47FBDD0D0>) in statistical functions.
# Level 1:tensorflow:Registering RealDiv,flops (<function _real_div_flops at 0x000001E47FBDD160>) in statistical functions.
# Level 1:tensorflow:Registering Maximum,flops (<function _maximum_flops at 0x000001E47FBDD1F0>) in statistical functions.
# Level 1:tensorflow:Registering Minimum,flops (<function _minimum_flops at 0x000001E47FBDD280>) in statistical functions.
# Level 1:tensorflow:Registering Pow,flops (<function _pow_flops at 0x000001E47FBDD3A0>) in statistical functions.
# Level 1:tensorflow:Registering RsqrtGrad,flops (<function _rsqrt_grad_flops at 0x000001E47FBDD4C0>) in statistical functions.
# Level 1:tensorflow:Registering GreaterEqual,flops (<function _greater_equal_flops at 0x000001E47FBDD430>) in statistical functions.
# Level 1:tensorflow:Registering Greater,flops (<function _greater_flops at 0x000001E47FBDD310>) in statistical functions.
# Level 1:tensorflow:Registering LessEqual,flops (<function _less_equal_flops at 0x000001E47FBDD550>) in statistical functions.
# Level 1:tensorflow:Registering Less,flops (<function _less_flops at 0x000001E47FBDD670>) in statistical functions.
# Level 1:tensorflow:Registering Equal,flops (<function _equal_flops at 0x000001E47FBDD700>) in statistical functions.
# Level 1:tensorflow:Registering NotEqual,flops (<function _not_equal_flops at 0x000001E47FBDD5E0>) in statistical functions.
# Level 1:tensorflow:Registering SquaredDifference,flops (<function _squared_difference_flops at 0x000001E47FBDD790>) in statistical functions.
# Level 1:tensorflow:Registering Mean,flops (<function _mean_flops at 0x000001E47FBDD940>) in statistical functions.
# Level 1:tensorflow:Registering Sum,flops (<function _sum_flops at 0x000001E47FBDD8B0>) in statistical functions.
# Level 1:tensorflow:Registering ArgMax,flops (<function _arg_max_flops at 0x000001E47FBDD9D0>) in statistical functions.
# Level 1:tensorflow:Registering ArgMin,flops (<function _arg_min_flops at 0x000001E47FBDDA60>) in statistical functions.
# Level 1:tensorflow:Registering BiasAddGrad,flops (<function _bias_add_grad_flops at 0x000001E47FBDDAF0>) in statistical functions.
# Level 1:tensorflow:Registering AvgPool,flops (<function _avg_pool_flops at 0x000001E47FBDDD30>) in statistical functions.
# Level 1:tensorflow:Registering MaxPool,flops (<function _max_pool_flops at 0x000001E47FBDDC10>) in statistical functions.
# Level 1:tensorflow:Registering AvgPoolGrad,flops (<function _avg_pool_grad_flops at 0x000001E47FBDDDC0>) in statistical functions.
# Level 1:tensorflow:Registering MaxPoolGrad,flops (<function _max_pool_grad_flops at 0x000001E47FBDDE50>) in statistical functions.
# Level 1:tensorflow:Registering Conv2DBackpropInput,flops (<function _conv_2d_backprop_input_flops at 0x000001E47FBDDEE0>) in statistical functions.
# Level 1:tensorflow:Registering Conv2DBackpropFilter,flops (<function _conv_2d_backprop_filter_flops at 0x000001E47FBDDF70>) in statistical functions.
# Level 1:tensorflow:Registering AddN,flops (<function _add_n_flops at 0x000001E47FBE1160>) in statistical functions.
# Level 1:tensorflow:Registering SdcaFprint (None) in gradient.
# Level 1:tensorflow:Registering SdcaOptimizer (None) in gradient.
# Level 1:tensorflow:Registering SdcaOptimizerV2 (None) in gradient.
# Level 1:tensorflow:Registering SdcaShrinkL1 (None) in gradient.
# Level 1:tensorflow:Registering GenerateVocabRemapping (None) in gradient.
# Level 1:tensorflow:Registering LoadAndRemapMatrix (None) in gradient.
# Level 1:tensorflow:Registering DebugGradientIdentity (<function _identify_gradient_grad at 0x000001E47779DD30>) in gradient.
# Level 1:tensorflow:Registering DebugGradientRefIdentity (<function _identify_gradient_grad_ref at 0x000001E4777A8550>) in gradient.
# Level 1:tensorflow:Registering DebugIdentityV2 (<function _debug_identity_v2_grad at 0x000001E47FC6F040>) in gradient.
# Level 1:tensorflow:Registering AudioMicrofrontend (None) in gradient.
# Level 1:tensorflow:Enabling eager execution
# Level 1:tensorflow:Enabling v2 tensorshape
# Level 1:tensorflow:Enabling resource variables
# Level 1:tensorflow:Enabling tensor equality
# Level 1:tensorflow:Enabling control flow v2

# %%
from deepClassifier.exception import CustomException
try:
    config = ConfigurationManager()
    prepare_base_model_config = config.get_prepare_base_model_config()
    prepare_base_model = PrepareBaseModel(config=prepare_base_model_config)
    prepare_base_model.get_base_model()
    prepare_base_model.update_base_model()
except Exception as e:
    raise CustomException(e, sys) from e
# Out:
# INFO:deepClassifier:yaml file: configs\config.yaml loaded successfully
# INFO:deepClassifier:yaml file: params.yaml loaded successfully
# INFO:deepClassifier:created directory at: artifacts
# INFO:deepClassifier:created directory at: artifacts/prepare_base_model
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dense_1 (Dense)             (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
